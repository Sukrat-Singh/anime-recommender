# %%
import numpy as np
import pandas as pd

# %%
anime = pd.read_csv('anime.csv')
rating = pd.read_csv('rating.csv')

# %%
print(anime.shape)
print(rating.shape)
# Out:
# (12294, 7)
# (7813737, 3)

# %%
anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
rating.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
rating['user_id'].nunique()
# Out:
# 73515

# %%
anime.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
rating.isnull().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
anime['rating'] = pd.to_numeric(anime['rating'], errors='coerce')  # converts to numeric(float64) type and replace the missing values with NaN
anime.dropna(subset=['rating'], inplace=True)   # dropping rows with NaN ratings
anime.reset_index(drop=True, inplace=True)  # reseting the index

# %%
anime['rating'].shape
# Out:
# (12064,)

# %%
anime['genre'] = anime['genre'].fillna("")
anime['genre'] = anime['genre'].str.lower()
# remove extra whitespace and split into list
anime['genre'] = anime['genre'].apply(lambda x: [g.strip() for g in x.split(',')] if x else [])

# %%
anime['genre'].head()
# Out:
# 0               [drama, romance, school, supernatural]
# 1    [action, adventure, drama, fantasy, magic, mil...
# 2    [action, comedy, historical, parody, samurai, ...
# 3                                   [sci-fi, thriller]
# 4    [action, comedy, historical, parody, samurai, ...
# Name: genre, dtype: object

# %%
anime['type'].unique()
# Out:
# array(['Movie', 'TV', 'OVA', 'Special', 'Music', 'ONA'], dtype=object)

# %%
anime['type'] = anime['type'].fillna("Unknown")
anime['type'] = anime['type'].str.lower().str.strip()

# %%
anime.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %% [markdown]
# # Polularity based Recommender System

# %% [markdown]
#  - We would simply sort the data according to average ratings and display top 250 book for our Popularity based system.
#  - We have cleaned the anime and rating dataset, after merging them, we can apply our algorithm.

# %%
merge_df = anime.merge(rating, on='anime_id')

# %%
merge_df.shape
# Out:
# (7813721, 9)

# %%
merge_df.head()
# Out:
#    anime_id            name                                   genre   type  \
# 0     32281  Kimi no Na wa.  [drama, romance, school, supernatural]  movie
# 1     32281  Kimi no Na wa.  [drama, romance, school, supernatural]  movie
# 2     32281  Kimi no Na wa.  [drama, romance, school, supernatural]  movie
# 3     32281  Kimi no Na wa.  [drama, romance, school, supernatural]  movie
# 4     32281  Kimi no Na wa.  [drama, romance, school, supernatural]  movie
#
#   episodes  rating_x  members  user_id  rating_y
# 0        1      9.37   200630       99         5
# 1        1      9.37   200630      152        10
# 2        1      9.37   200630      244        10
# 3        1      9.37   200630      271        10
# 4        1      9.37   200630      278        -1

# %%
merge_df = merge_df.rename(columns={'rating_x': 'avg_rating', 'rating_y': 'user_rating'})

# %%
temp_df = merge_df.groupby(['name']).count()['members'].reset_index()
temp_df = temp_df.rename(columns={'members': 'num_rating'})
temp_df
# Out:
#                                                     name  num_rating
# 0                                          &quot;0&quot;          26
# 1      &quot;Aesop&quot; no Ohanashi yori: Ushi to Ka...           2
# 2      &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hat...         782
# 3                     &quot;Bungaku Shoujo&quot; Memoire         809
# 4                       &quot;Bungaku Shoujo&quot; Movie        1535
# ...                                                  ...         ...
# 11188                                       xxxHOLiC Kei        3413
# 11189            xxxHOLiC Movie: Manatsu no Yoru no Yume        2365
# 11190                                       xxxHOLiC Rou        1513
# 11191                                  xxxHOLiC Shunmuki        1974
# 11192                                                  ◯           6
#
# [11193 rows x 2 columns]

# %%
avg_df = merge_df.drop(columns = ['members', 'user_id', 'user_rating'])
avg_df = avg_df.drop_duplicates(subset=['name'])
avg_df
# Out:
#          anime_id                                               name  \
# 0           32281                                     Kimi no Na wa.
# 2199         5114                   Fullmetal Alchemist: Brotherhood
# 26773       28977                                           Gintama°
# 28159        9253                                        Steins;Gate
# 47442        9969                                      Gintama&#039;
# ...           ...                                                ...
# 7813704      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 7813708      5543                                        Under World
# 7813712      5621                     Violence Gekiga David no Hoshi
# 7813715      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813719     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                      genre   type episodes  \
# 0                   [drama, romance, school, supernatural]  movie        1
# 2199     [action, adventure, drama, fantasy, magic, mil...     tv       64
# 26773    [action, comedy, historical, parody, samurai, ...     tv       51
# 28159                                   [sci-fi, thriller]     tv       24
# 47442    [action, comedy, historical, parody, samurai, ...     tv       51
# ...                                                    ...    ...      ...
# 7813704                                           [hentai]    ova        1
# 7813708                                           [hentai]    ova        1
# 7813712                                           [hentai]    ova        4
# 7813715                                           [hentai]    ova        1
# 7813719                                           [hentai]  movie        1
#
#          avg_rating
# 0              9.37
# 2199           9.26
# 26773          9.25
# 28159          9.17
# 47442          9.16
# ...             ...
# 7813704        4.15
# 7813708        4.28
# 7813712        4.88
# 7813715        4.98
# 7813719        5.46
#
# [11193 rows x 6 columns]

# %%
avg_df = avg_df.merge(temp_df, on='name')
avg_df
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 11188      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 11189      5543                                        Under World
# 11190      5621                     Violence Gekiga David no Hoshi
# 11191      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 11192     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                 [drama, romance, school, supernatural]  movie        1
# 1      [action, adventure, drama, fantasy, magic, mil...     tv       64
# 2      [action, comedy, historical, parody, samurai, ...     tv       51
# 3                                     [sci-fi, thriller]     tv       24
# 4      [action, comedy, historical, parody, samurai, ...     tv       51
# ...                                                  ...    ...      ...
# 11188                                           [hentai]    ova        1
# 11189                                           [hentai]    ova        1
# 11190                                           [hentai]    ova        4
# 11191                                           [hentai]    ova        1
# 11192                                           [hentai]  movie        1
#
#        avg_rating  num_rating
# 0            9.37        2199
# 1            9.26       24574
# 2            9.25        1386
# 3            9.17       19283
# 4            9.16        3673
# ...           ...         ...
# 11188        4.15           4
# 11189        4.28           4
# 11190        4.88           3
# 11191        4.98           4
# 11192        5.46           2
#
# [11193 rows x 7 columns]

# %%
popular_df = avg_df[avg_df['num_rating']>=250].sort_values('avg_rating', ascending=False).head(100)

# %%
popular_df
# Out:
#      anime_id                                               name  \
# 0       32281                                     Kimi no Na wa.
# 1        5114                   Fullmetal Alchemist: Brotherhood
# 2       28977                                           Gintama°
# 3        9253                                        Steins;Gate
# 4        9969                                      Gintama&#039;
# ..        ...                                                ...
# 97      18115                         Magi: The Kingdom of Magic
# 96      30230                      Diamond no Ace: Second Season
# 94      13601                                        Psycho-Pass
# 102      6594                                       Katanagatari
# 103     11979  Mahou Shoujo Madoka★Magica Movie 2: Eien no Mo...
#
#                                                  genre   type episodes  \
# 0               [drama, romance, school, supernatural]  movie        1
# 1    [action, adventure, drama, fantasy, magic, mil...     tv       64
# 2    [action, comedy, historical, parody, samurai, ...     tv       51
# 3                                   [sci-fi, thriller]     tv       24
# 4    [action, comedy, historical, parody, samurai, ...     tv       51
# ..                                                 ...    ...      ...
# 97        [action, adventure, fantasy, magic, shounen]     tv       25
# 96                   [comedy, school, shounen, sports]     tv       51
# 94             [action, police, psychological, sci-fi]     tv       22
# 102  [action, adventure, historical, martial arts, ...     tv       12
# 103            [drama, magic, psychological, thriller]  movie        1
#
#      avg_rating  num_rating
# 0          9.37        2199
# 1          9.26       24574
# 2          9.25        1386
# 3          9.17       19283
# 4          9.16        3673
# ..          ...         ...
# 97         8.50        7279
# 96         8.50         868
# 94         8.50       14008
# 102        8.49        5317
# 103        8.49        3014
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Collabroative Filtering Recommender System

# %%
rating_df = rating[rating['rating']!=-1].reset_index()
rating_df = rating_df.drop(columns={"index"})
rating_df
# Out:
#          user_id  anime_id  rating
# 0              1      8074      10
# 1              1     11617      10
# 2              1     11757      10
# 3              1     15451      10
# 4              2     11771      10
# ...          ...       ...     ...
# 6337236    73515     16512       7
# 6337237    73515     17187       9
# 6337238    73515     22145      10
# 6337239    73516       790       9
# 6337240    73516      8074       9
#
# [6337241 rows x 3 columns]

# %% [markdown]
# #### We will count only those users which have rated only above a certain threshold number of ratings, i.e. on the basis of activeness.

# %%
# threshold = 250 number of ratings
x = rating.groupby(['user_id']).count()['rating']>=250
active_user_ids = x[x].index

# %%
rating_info = rating_df[rating_df['user_id'].isin(active_user_ids)]

# %%
rating_info = rating_info.reset_index().drop(columns={"index"})
rating_info
# Out:
#          user_id  anime_id  rating
# 0              5         6       8
# 1              5        15       6
# 2              5        17       6
# 3              5        18       6
# 4              5        20       6
# ...          ...       ...     ...
# 2762254    73507      8231       5
# 2762255    73507      8348       5
# 2762256    73507      8440       7
# 2762257    73507      8769       8
# 2762258    73507     10067       5
#
# [2762259 rows x 3 columns]

# %% [markdown]
# #### Also, we will consider only those animes who have been rated for atleast a certain amount of thershold.

# %%
# threshold = 50 ratings on an anime
anime_rating_counts = rating.groupby('anime_id').size()
popular_anime_ids = anime_rating_counts[anime_rating_counts >= 50].index
popular_animes = anime[anime['anime_id'].isin(popular_anime_ids)]
popular_animes
# Out:
#        anime_id                              name  \
# 0         32281                    Kimi no Na wa.
# 1          5114  Fullmetal Alchemist: Brotherhood
# 2         28977                          Gintama°
# 3          9253                       Steins;Gate
# 4          9969                     Gintama&#039;
# ...         ...                               ...
# 11987      6546      Pico: My Little Summer Story
# 11989      5391                     Pico to Chico
# 11992      3635                     Advancer Tina
# 11993      4866               Pico x CoCo x Chico
# 11997      1639                      Boku no Pico
#
#                                                    genre   type episodes  \
# 0                 [drama, romance, school, supernatural]  movie        1
# 1      [action, adventure, drama, fantasy, magic, mil...     tv       64
# 2      [action, comedy, historical, parody, samurai, ...     tv       51
# 3                                     [sci-fi, thriller]     tv       24
# 4      [action, comedy, historical, parody, samurai, ...     tv       51
# ...                                                  ...    ...      ...
# 11987                                             [yaoi]    ova        1
# 11989                                     [hentai, yaoi]    ova        1
# 11992                            [hentai, sci-fi, space]    ova        1
# 11993                                     [hentai, yaoi]    ova        1
# 11997                                     [hentai, yaoi]    ova        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 11987    5.21     5551
# 11989    5.19    29463
# 11992    5.16     1487
# 11993    5.16    27411
# 11997    5.13    57355
#
# [5651 rows x 7 columns]

# %% [markdown]
#  - 7591 users have given more than threshold number of ratings.
#  - 5651 animes have recieved ratings by more than threshold number of users.

# %%
anime_df = popular_animes.merge(rating_info, on='anime_id')
anime_df = anime_df.rename(columns={"rating_x": "avg_rating", "rating_y": "user_rating"})
anime_df
# Out:
#          anime_id            name                                   genre  \
# 0           32281  Kimi no Na wa.  [drama, romance, school, supernatural]
# 1           32281  Kimi no Na wa.  [drama, romance, school, supernatural]
# 2           32281  Kimi no Na wa.  [drama, romance, school, supernatural]
# 3           32281  Kimi no Na wa.  [drama, romance, school, supernatural]
# 4           32281  Kimi no Na wa.  [drama, romance, school, supernatural]
# ...           ...             ...                                     ...
# 2728349      1639    Boku no Pico                          [hentai, yaoi]
# 2728350      1639    Boku no Pico                          [hentai, yaoi]
# 2728351      1639    Boku no Pico                          [hentai, yaoi]
# 2728352      1639    Boku no Pico                          [hentai, yaoi]
# 2728353      1639    Boku no Pico                          [hentai, yaoi]
#
#           type episodes  avg_rating  members  user_id  user_rating
# 0        movie        1        9.37   200630      244           10
# 1        movie        1        9.37   200630      271           10
# 2        movie        1        9.37   200630      462            8
# 3        movie        1        9.37   200630      784            9
# 4        movie        1        9.37   200630      786           10
# ...        ...      ...         ...      ...      ...          ...
# 2728349    ova        1        5.13    57355    73135            2
# 2728350    ova        1        5.13    57355    73162           10
# 2728351    ova        1        5.13    57355    73328            2
# 2728352    ova        1        5.13    57355    73329            6
# 2728353    ova        1        5.13    57355    73389            7
#
# [2728354 rows x 9 columns]

# %%
table_df = anime_df.pivot_table(index="name", columns="user_id", values="user_rating")

# %%
table_df.fillna(0, inplace=True)

# %%
table_df
# Out:
# user_id                                             5      7      17     \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
# ...                                                   ...    ...    ...
# xxxHOLiC                                              2.0    0.0    0.0
# xxxHOLiC Kei                                          0.0    0.0    0.0
# xxxHOLiC Movie: Manatsu no Yoru no Yume               0.0    0.0    0.0
# xxxHOLiC Rou                                          0.0    0.0    0.0
# xxxHOLiC Shunmuki                                     0.0    0.0    0.0
#
# user_id                                             38     43     46     \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
# ...                                                   ...    ...    ...
# xxxHOLiC                                              0.0    7.0    0.0
# xxxHOLiC Kei                                          0.0    7.0    0.0
# xxxHOLiC Movie: Manatsu no Yoru no Yume               0.0    0.0    0.0
# xxxHOLiC Rou                                          0.0    0.0    0.0
# xxxHOLiC Shunmuki                                     0.0    7.0    0.0
#
# user_id                                             123    139    160    \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    7.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    8.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    8.0
# .hack//G.U. Returner                                  0.0    0.0    8.0
# .hack//G.U. Trilogy                                   0.0    0.0    8.0
# ...                                                   ...    ...    ...
# xxxHOLiC                                              0.0    0.0    8.0
# xxxHOLiC Kei                                          0.0    0.0    8.0
# xxxHOLiC Movie: Manatsu no Yoru no Yume               0.0    0.0    0.0
# xxxHOLiC Rou                                          0.0    0.0    8.0
# xxxHOLiC Shunmuki                                     0.0    0.0    9.0
#
# user_id                                             198    ...  73406  73408  \
# name                                                       ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0  ...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0  ...    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0  ...    0.0    0.0
# .hack//G.U. Returner                                  0.0  ...    0.0    0.0
# .hack//G.U. Trilogy                                   0.0  ...    0.0    0.0
# ...                                                   ...  ...    ...    ...
# xxxHOLiC                                              0.0  ...   10.0    0.0
# xxxHOLiC Kei                                          0.0  ...   10.0    0.0
# xxxHOLiC Movie: Manatsu no Yoru no Yume               0.0  ...    9.0    0.0
# xxxHOLiC Rou                                          0.0  ...   10.0    0.0
# xxxHOLiC Shunmuki                                     0.0  ...    9.0    0.0
#
# user_id                                             73417  73422  73457  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
# ...                                                   ...    ...    ...
# xxxHOLiC                                              7.0    0.0    0.0
# xxxHOLiC Kei                                          0.0    0.0    0.0
# xxxHOLiC Movie: Manatsu no Yoru no Yume               0.0    0.0    0.0
# xxxHOLiC Rou                                          0.0    0.0    0.0
# xxxHOLiC Shunmuki                                     0.0    0.0    0.0
#
# user_id                                             73476  73491  73499  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                      0.0    0.0    0.0
# .hack//G.U. Returner                                  0.0    0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0    0.0
# ...                                                   ...    ...    ...
# xxxHOLiC                                              0.0    0.0    0.0
# xxxHOLiC Kei                                          0.0    0.0    0.0
# xxxHOLiC Movie: Manatsu no Yoru no Yume               0.0    0.0    0.0
# xxxHOLiC Rou                                          0.0    0.0    0.0
# xxxHOLiC Shunmuki                                     0.0    0.0    0.0
#
# user_id                                             73502  73507
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...   10.0    0.0
# &quot;Bungaku Shoujo&quot; Memoire                    0.0    0.0
# &quot;Bungaku Shoujo&quot; Movie                     10.0    0.0
# .hack//G.U. Returner                                  0.0    0.0
# .hack//G.U. Trilogy                                   0.0    0.0
# ...                                                   ...    ...
# xxxHOLiC                                             10.0   10.0
# xxxHOLiC Kei                                         10.0    9.0
# xxxHOLiC Movie: Manatsu no Yoru no Yume              10.0    9.0
# xxxHOLiC Rou                                          0.0    0.0
# xxxHOLiC Shunmuki                                    10.0    9.0
#
# [5651 rows x 7590 columns]

# %% [markdown]
#  - `0`: not rated
#  - `[1, 10]`: rating give by users to animes

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cos_sim_matrix = cosine_similarity(table_df.values)
cos_sim_df = pd.DataFrame(cos_sim_matrix, index=table_df.index, columns=table_df.index)

# %%
cos_sim_matrix.shape
# Out:
# (5651, 5651)

# %%
cos_sim_df
# Out:
# name                                                &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                           1.000000
# &quot;Bungaku Shoujo&quot; Memoire                                                           0.714473
# &quot;Bungaku Shoujo&quot; Movie                                                             0.600464
# .hack//G.U. Returner                                                                         0.112421
# .hack//G.U. Trilogy                                                                          0.124191
# ...                                                                                               ...
# xxxHOLiC                                                                                     0.213716
# xxxHOLiC Kei                                                                                 0.194587
# xxxHOLiC Movie: Manatsu no Yoru no Yume                                                      0.208980
# xxxHOLiC Rou                                                                                 0.186988
# xxxHOLiC Shunmuki                                                                            0.207572
#
# name                                                &quot;Bungaku Shoujo&quot; Memoire  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                            0.714473
# &quot;Bungaku Shoujo&quot; Memoire                                            1.000000
# &quot;Bungaku Shoujo&quot; Movie                                              0.693933
# .hack//G.U. Returner                                                          0.116556
# .hack//G.U. Trilogy                                                           0.129184
# ...                                                                                ...
# xxxHOLiC                                                                      0.209256
# xxxHOLiC Kei                                                                  0.197884
# xxxHOLiC Movie: Manatsu no Yoru no Yume                                       0.192762
# xxxHOLiC Rou                                                                  0.199059
# xxxHOLiC Shunmuki                                                             0.204893
#
# name                                                &quot;Bungaku Shoujo&quot; Movie  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                          0.600464
# &quot;Bungaku Shoujo&quot; Memoire                                          0.693933
# &quot;Bungaku Shoujo&quot; Movie                                            1.000000
# .hack//G.U. Returner                                                        0.119488
# .hack//G.U. Trilogy                                                         0.138284
# ...                                                                              ...
# xxxHOLiC                                                                    0.228879
# xxxHOLiC Kei                                                                0.211343
# xxxHOLiC Movie: Manatsu no Yoru no Yume                                     0.196500
# xxxHOLiC Rou                                                                0.201723
# xxxHOLiC Shunmuki                                                           0.205417
#
# name                                                .hack//G.U. Returner  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...              0.112421
# &quot;Bungaku Shoujo&quot; Memoire                              0.116556
# &quot;Bungaku Shoujo&quot; Movie                                0.119488
# .hack//G.U. Returner                                            1.000000
# .hack//G.U. Trilogy                                             0.702022
# ...                                                                  ...
# xxxHOLiC                                                        0.174164
# xxxHOLiC Kei                                                    0.173973
# xxxHOLiC Movie: Manatsu no Yoru no Yume                         0.176642
# xxxHOLiC Rou                                                    0.144603
# xxxHOLiC Shunmuki                                               0.157140
#
# name                                                .hack//G.U. Trilogy  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...             0.124191
# &quot;Bungaku Shoujo&quot; Memoire                             0.129184
# &quot;Bungaku Shoujo&quot; Movie                               0.138284
# .hack//G.U. Returner                                           0.702022
# .hack//G.U. Trilogy                                            1.000000
# ...                                                                 ...
# xxxHOLiC                                                       0.203232
# xxxHOLiC Kei                                                   0.187575
# xxxHOLiC Movie: Manatsu no Yoru no Yume                        0.183660
# xxxHOLiC Rou                                                   0.144203
# xxxHOLiC Shunmuki                                              0.159959
#
# name                                                .hack//G.U. Trilogy: Parody Mode  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                          0.096794
# &quot;Bungaku Shoujo&quot; Memoire                                          0.097077
# &quot;Bungaku Shoujo&quot; Movie                                            0.105241
# .hack//G.U. Returner                                                        0.607083
# .hack//G.U. Trilogy                                                         0.559520
# ...                                                                              ...
# xxxHOLiC                                                                    0.123275
# xxxHOLiC Kei                                                                0.121789
# xxxHOLiC Movie: Manatsu no Yoru no Yume                                     0.128790
# xxxHOLiC Rou                                                                0.109326
# xxxHOLiC Shunmuki                                                           0.119663
#
# name                                                .hack//Gift  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...     0.111659
# &quot;Bungaku Shoujo&quot; Memoire                     0.107346
# &quot;Bungaku Shoujo&quot; Movie                       0.100445
# .hack//G.U. Returner                                   0.616287
# .hack//G.U. Trilogy                                    0.508921
# ...                                                         ...
# xxxHOLiC                                               0.175262
# xxxHOLiC Kei                                           0.156764
# xxxHOLiC Movie: Manatsu no Yoru no Yume                0.183311
# xxxHOLiC Rou                                           0.112494
# xxxHOLiC Shunmuki                                      0.133482
#
# name                                                .hack//Intermezzo  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.117260
# &quot;Bungaku Shoujo&quot; Memoire                           0.119599
# &quot;Bungaku Shoujo&quot; Movie                             0.120592
# .hack//G.U. Returner                                         0.581958
# .hack//G.U. Trilogy                                          0.486578
# ...                                                               ...
# xxxHOLiC                                                     0.201100
# xxxHOLiC Kei                                                 0.185137
# xxxHOLiC Movie: Manatsu no Yoru no Yume                      0.207260
# xxxHOLiC Rou                                                 0.141131
# xxxHOLiC Shunmuki                                            0.162783
#
# name                                                .hack//Liminality  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.121106
# &quot;Bungaku Shoujo&quot; Memoire                           0.122896
# &quot;Bungaku Shoujo&quot; Movie                             0.121001
# .hack//G.U. Returner                                         0.555288
# .hack//G.U. Trilogy                                          0.530734
# ...                                                               ...
# xxxHOLiC                                                     0.224763
# xxxHOLiC Kei                                                 0.196142
# xxxHOLiC Movie: Manatsu no Yoru no Yume                      0.195678
# xxxHOLiC Rou                                                 0.119387
# xxxHOLiC Shunmuki                                            0.155371
#
# name                                                .hack//Quantum  ...  \
# name                                                                ...
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...        0.152381  ...
# &quot;Bungaku Shoujo&quot; Memoire                        0.140153  ...
# &quot;Bungaku Shoujo&quot; Movie                          0.145927  ...
# .hack//G.U. Returner                                      0.462214  ...
# .hack//G.U. Trilogy                                       0.477772  ...
# ...                                                            ...  ...
# xxxHOLiC                                                  0.201171  ...
# xxxHOLiC Kei                                              0.169994  ...
# xxxHOLiC Movie: Manatsu no Yoru no Yume                   0.172197  ...
# xxxHOLiC Rou                                              0.151276  ...
# xxxHOLiC Shunmuki                                         0.171660  ...
#
# name                                                ef: A Tale of Memories.  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                 0.287564
# &quot;Bungaku Shoujo&quot; Memoire                                 0.292886
# &quot;Bungaku Shoujo&quot; Movie                                   0.356924
# .hack//G.U. Returner                                               0.183452
# .hack//G.U. Trilogy                                                0.191803
# ...                                                                     ...
# xxxHOLiC                                                           0.362995
# xxxHOLiC Kei                                                       0.333315
# xxxHOLiC Movie: Manatsu no Yoru no Yume                            0.278948
# xxxHOLiC Rou                                                       0.242704
# xxxHOLiC Shunmuki                                                  0.277415
#
# name                                                ef: A Tale of Memories. - Prologue  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                            0.259599
# &quot;Bungaku Shoujo&quot; Memoire                                            0.235784
# &quot;Bungaku Shoujo&quot; Movie                                              0.230178
# .hack//G.U. Returner                                                          0.141754
# .hack//G.U. Trilogy                                                           0.131747
# ...                                                                                ...
# xxxHOLiC                                                                      0.171177
# xxxHOLiC Kei                                                                  0.161631
# xxxHOLiC Movie: Manatsu no Yoru no Yume                                       0.178285
# xxxHOLiC Rou                                                                  0.158698
# xxxHOLiC Shunmuki                                                             0.174469
#
# name                                                ef: A Tale of Memories. - Recollections  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                 0.189008
# &quot;Bungaku Shoujo&quot; Memoire                                                 0.180317
# &quot;Bungaku Shoujo&quot; Movie                                                   0.156416
# .hack//G.U. Returner                                                               0.115159
# .hack//G.U. Trilogy                                                                0.097020
# ...                                                                                     ...
# xxxHOLiC                                                                           0.111558
# xxxHOLiC Kei                                                                       0.108802
# xxxHOLiC Movie: Manatsu no Yoru no Yume                                            0.125436
# xxxHOLiC Rou                                                                       0.107981
# xxxHOLiC Shunmuki                                                                  0.113947
#
# name                                                iDOLM@STER Xenoglossia  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                0.127990
# &quot;Bungaku Shoujo&quot; Memoire                                0.125370
# &quot;Bungaku Shoujo&quot; Movie                                  0.123036
# .hack//G.U. Returner                                              0.069591
# .hack//G.U. Trilogy                                               0.105485
# ...                                                                    ...
# xxxHOLiC                                                          0.149044
# xxxHOLiC Kei                                                      0.131600
# xxxHOLiC Movie: Manatsu no Yoru no Yume                           0.122538
# xxxHOLiC Rou                                                      0.079149
# xxxHOLiC Shunmuki                                                 0.087932
#
# name                                                s.CRY.ed  xxxHOLiC  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...  0.078058  0.213716
# &quot;Bungaku Shoujo&quot; Memoire                  0.090451  0.209256
# &quot;Bungaku Shoujo&quot; Movie                    0.110009  0.228879
# .hack//G.U. Returner                                0.111401  0.174164
# .hack//G.U. Trilogy                                 0.164752  0.203232
# ...                                                      ...       ...
# xxxHOLiC                                            0.243393  1.000000
# xxxHOLiC Kei                                        0.198827  0.858157
# xxxHOLiC Movie: Manatsu no Yoru no Yume             0.177028  0.679840
# xxxHOLiC Rou                                        0.120910  0.631906
# xxxHOLiC Shunmuki                                   0.141581  0.686436
#
# name                                                xxxHOLiC Kei  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.194587
# &quot;Bungaku Shoujo&quot; Memoire                      0.197884
# &quot;Bungaku Shoujo&quot; Movie                        0.211343
# .hack//G.U. Returner                                    0.173973
# .hack//G.U. Trilogy                                     0.187575
# ...                                                          ...
# xxxHOLiC                                                0.858157
# xxxHOLiC Kei                                            1.000000
# xxxHOLiC Movie: Manatsu no Yoru no Yume                 0.687903
# xxxHOLiC Rou                                            0.720312
# xxxHOLiC Shunmuki                                       0.784527
#
# name                                                xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...                                 0.208980
# &quot;Bungaku Shoujo&quot; Memoire                                                 0.192762
# &quot;Bungaku Shoujo&quot; Movie                                                   0.196500
# .hack//G.U. Returner                                                               0.176642
# .hack//G.U. Trilogy                                                                0.183660
# ...                                                                                     ...
# xxxHOLiC                                                                           0.679840
# xxxHOLiC Kei                                                                       0.687903
# xxxHOLiC Movie: Manatsu no Yoru no Yume                                            1.000000
# xxxHOLiC Rou                                                                       0.615022
# xxxHOLiC Shunmuki                                                                  0.684437
#
# name                                                xxxHOLiC Rou  \
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...      0.186988
# &quot;Bungaku Shoujo&quot; Memoire                      0.199059
# &quot;Bungaku Shoujo&quot; Movie                        0.201723
# .hack//G.U. Returner                                    0.144603
# .hack//G.U. Trilogy                                     0.144203
# ...                                                          ...
# xxxHOLiC                                                0.631906
# xxxHOLiC Kei                                            0.720312
# xxxHOLiC Movie: Manatsu no Yoru no Yume                 0.615022
# xxxHOLiC Rou                                            1.000000
# xxxHOLiC Shunmuki                                       0.825829
#
# name                                                xxxHOLiC Shunmuki
# name
# &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hats...           0.207572
# &quot;Bungaku Shoujo&quot; Memoire                           0.204893
# &quot;Bungaku Shoujo&quot; Movie                             0.205417
# .hack//G.U. Returner                                         0.157140
# .hack//G.U. Trilogy                                          0.159959
# ...                                                               ...
# xxxHOLiC                                                     0.686436
# xxxHOLiC Kei                                                 0.784527
# xxxHOLiC Movie: Manatsu no Yoru no Yume                      0.684437
# xxxHOLiC Rou                                                 0.825829
# xxxHOLiC Shunmuki                                            1.000000
#
# [5651 rows x 5651 columns]

# %%
from difflib import get_close_matches

def recommend(anime_name, top_n=10):
    if anime_name not in cos_sim_df.index:
        close_match = get_close_matches(anime_name, cos_sim_df.index, n=1)
        if close_match:
            anime_name = close_match[0]
        else:
            return f"'{anime_name}' not found in anime list."
    
    similar_animes = cos_sim_df[anime_name].sort_values(ascending=False).iloc[1:top_n+1]
    return pd.DataFrame({
        'Recommended Anime': similar_animes.index,
        'Similarity Score': similar_animes.values
    })

# %%
recommend("death note", 20)
# Out:
#                      Recommended Anime  Similarity Score
# 0      Code Geass: Hangyaku no Lelouch          0.808323
# 1   Code Geass: Hangyaku no Lelouch R2          0.792399
# 2                           Elfen Lied          0.762357
# 3     Fullmetal Alchemist: Brotherhood          0.758946
# 4                         Angel Beats!          0.754108
# 5                   Shingeki no Kyojin          0.751726
# 6                            Toradora!          0.743203
# 7                     Sword Art Online          0.733730
# 8                  Fullmetal Alchemist          0.732552
# 9                          Steins;Gate          0.728813
# 10              Highschool of the Dead          0.728675
# 11                          Durarara!!          0.726034
# 12                             Clannad          0.716928
# 13                    Mirai Nikki (TV)          0.716044
# 14                              Naruto          0.711055
# 15          Tengen Toppa Gurren Lagann          0.708796
# 16          Suzumiya Haruhi no Yuuutsu          0.706522
# 17                      Bakemonogatari          0.705128
# 18                      Ao no Exorcist          0.701138
# 19                             Another          0.697691

# %%
import pickle

# %%
with open('pivot_table.pkl', 'wb') as f:
    pickle.dump(table_df, f)

# %%
with open('cos_sim_df.pkl', 'wb') as f:
    pickle.dump(cos_sim_df, f)

# %%
import html

# Apply unescape to 'name' and optionally 'genre'
popular_df['name'] = popular_df['name'].apply(html.unescape)
popular_df['genre'] = popular_df['genre'].apply(html.unescape)

# Save again after cleaning
popular_df.to_csv("top_100_df.csv", index=False)
